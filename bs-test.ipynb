# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://dhhrm.catalogaccess.com/photos/4424'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>PastPerfect</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/bundles/styles?v=kyjb7FoYU10scb0B9l4vVEazjlkr_85Rn-rjNRX_hqE1" rel="stylesheet"/>
# <link href="https://dhhrm.catalogaccess.com/api/appearance/css" rel="stylesheet"/>
# <script type="text/javascript">
#         var CLIENT_ROUTES = {"Home":"home","Search":"search","AdvancedSearch":"advanced-search","RandomImages":"random-images","Images":"images","Archives":"archives","Library":"library","Objects":"objects","Photos":"photos","Exhibits":"exhibits","People":"people","Containers":"containers","SearchTerms":"search-terms","Sites":"sites","NotFound":"not-found","Authorization":"authorization"};
#     </script>
# <meta content="-r8uv8dvwRLUO31n2y0D_EJbSmBaryiZdzeJCHoOmX4" name="google-site-verification">
# <link href="https://use.typekit.net/aoy7xbg.css" rel="stylesheet"/>
# </meta></head>
# <body>
# <header class="col-md-12 col-sm-12 col-xs-12">
# <div class="container"><a href="https://www.dhhrm.org/" target="_blank"><img alt="Dallas Holocaust and Human Rights Museum" src="https://s3.amazonaws.com/ppwebassets/release/39181/e2ee33f4-ee26-4627-88be-fc56fc286b4a.svg" style="height:113px; width:200px"/></a></div>
# </header>
# <div data-bind="css: { 'container': app.isSideNav() }">
# <!-- ko with: navigationViewModel -->
# <div data-bind="css: { 'container col-md-2 col-sm-2': app.isSideNav() }" id="navigation">
# <nav class="navbar navbar-default" data-bind="css: orientation" id="main-navigation-menu" role="navigation">
# <div class="container-fluid" data-bind="css: { 'row': app.isSideNav() }">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" data-bind="css: { 'row': app.isSideNav() }" id="navbar-collapse">
# <ul class="nav nav-pills" data-bind="css: { 'nav-stacked': OrientationId() == 2 }">
# <li class="active" id="home-link"><a href="https://dhhrm.catalogaccess.com/home">Featured Collections</a></li>
# <li id="search-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/search">Keyword Search</a></li>
# <li id="advanced-search-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/advanced-search">Advanced Search</a></li>
# <li id="images-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/random-images">Random Images</a></li>
# <li id="archives-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/archives">Documents</a></li>
# <li id="library-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/library">Rare Books</a></li>
# <li id="objects-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/objects">Artifacts</a></li>
# <li id="photos-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/photos">Photos</a></li>
# <li id="exhibits-link"><a data-bind="click: app.router.triggerNavigation" href="https://dhhrm.catalogaccess.com/exhibits">Exhibits</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <!-- /ko -->
# <main class="container" data-bind="css: { 'col-md-10 col-sm-10': app.isSideNav(), 'col-md-12 col-sm-12': !app.isSideNav() }" id="content-body">
# <div data-bind="visible: isLoading" id="page-loader">
# <div class="page-loader">
# <div class="spinner">
# <div class="rect1"></div>
# <div class="rect2"></div>
# <div class="rect3"></div>
# <div class="rect4"></div>
# <div class="rect5"></div>
# </div>
# </div>
# </div>
# <!-- ko with: currentViewModel -->
# <div data-bind="template: { name: templateId, data: $data }, css: { 'container': !app.isSideNav() }, visible: !$parent.isLoading()">
# </div>
# <!-- /ko -->
# </main>
# </div>
# <div class="clearfix"></div>
# <footer>
# <div class="container">
# <a href="https://www.dhhrm.org/" target="_blank"><img alt="Dallas Holocaust and Human Rights Museum" src="https://s3.amazonaws.com/ppwebassets/release/39181/e2ee33f4-ee26-4627-88be-fc56fc286b4a.svg" style="height:113px; width:200px"/></a><br/>
# 300 N. Houston St. | Dallas, TX 75202<br/>
# Phone: (469) 399-5220<br/>
# <a href="https://www.dhhrm.org/" target="_blank">dhhrm.org</a><br/>
# Email: <a href="mailto:archives@dhhrm.org">archives@dhhrm.org</a>
# </div>
# </footer>
# <div id="page-templates"></div>
# <div class="privacy-container" data-bind="visible: !app.isPrivacyAccepted()" style="display: none">
# <p>Your privacy</p>
# <p>
#         We use cookies on our website to improve your experience. By continuing to enjoy our site, you are agreeing to our use of cookies.
#     </p>
# <button class="btn btn-outline-primary agree-btn" data-bind="click: app.acceptCookies">I agree</button>
# </div>
# <script src="/bundles/libs?v=h4FYGwxfKimL9Lj215yB6XpT0f_-mejGp-zv11iqNCk1" type="text/javascript"></script>
# <script async="" src="/bundles/app?v=yz21RnP6QliqVeMXPlDfCjN-jj_ckxbKpcn71fVZRqk1" type="text/javascript"></script>
# <script async="" type="text/javascript">
#         var header = "";
# var message = "The Dallas Holocaust and Human Rights Museum is committed to making archival records and oral history testimonies documenting the Holocaust and human rights topics accessible. Some materials may contain disturbing images or descriptions. We provide scholars and members of the general public access to this material in support of the Museum's mission to teach the history of the Holocaust and advance human rights to combat prejudice, hatred, and indifference.  We do not edit or sanitize historical materials to align with any viewpoint.";
#
# // Uncomment this line if you want to show info message each time user refresh the page
# // $(function() { showTextModal(header, message) });
#
# // This code shows message only once per session
# var sessionStorageKey = "INFO_MESSAGE_SHOWN";
# $(function() {
#     if (!sessionStorage.getItem(sessionStorageKey)) {
#         showTextModal(header, message);
#         sessionStorage.setItem(sessionStorageKey, true);
#     }
# });
#     </script>
# <template id="text-input-component">
# <span class="input-container" data-bind="validationOptions: validationOptions">
# <input class="form-control validation-input" data-bind="value: value, attr: { 'readonly': isDisabled, 'id': id }, event: { input: onInput, focusout: onLostFocus }, valueUpdate: valueUpdate"/>
# <span class="validation-message" data-bind="validationMessage: value"></span>
# </span>
# </template>
# <template id="search-control-component">
# <div data-bind="css: containerClass, validationOptions: validationOptions">
# <!-- ko if: icon -->
# <span class="search-control-icon" data-bind="css: icon"></span>
# <!-- /ko -->
# <input data-bind="value: searchString,
#                           valueUpdate: valueUpdate,
#                           event: { keypress: onEnterPress },
#                           enable: enable,
#                           css: inputClass,
#                           attr: { id, title, placeholder, 'aria-label': ariaLabel }" type="text"/>
# <!-- ko if: isNotEmpty -->
# <button data-bind="click: clear, enable: enable" title="Click to clear the search criteria" type="reset">
#             ×
#         </button>
# <!-- /ko -->
# </div>
# <span class="validation-message" data-bind="validationMessage: searchString"></span>
# </template>
# <template id="async-action-button-component">
# <button data-bind="verifiedSubmit: click, modelToValidate: modelToValidate, enable: !isInProgress(), css: buttonClass, visible: visible" type="button">
# <span aria-hidden="true" data-bind="css: spinnerClass, visible: isInProgress"></span>
# <span data-bind="text: text" role="status"></span>
# </button>
# </template>
# </body>
# </html>
